# %%
pip install prettytable
# Out:
# Requirement already satisfied: prettytable in c:\users\j. afolayan\anaconda3\lib\site-packages (3.3.0)
# Requirement already satisfied: wcwidth in c:\users\j. afolayan\anaconda3\lib\site-packages (from prettytable) (0.2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import requests
import pandas as pd
from prettytable import PrettyTable
import json
import csv

# %%
#Create a table object Pretty table
tableobj = PrettyTable()
KeyVal = '12608f89-09da-41c1-8353-bc854d8c5f85'

# %%
api_endpoint = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?CMC_PRO_API_KEY='
api_endpoint += KeyVal
api_endpoint
# Out:
# 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?CMC_PRO_API_KEY=12608f89-09da-41c1-8353-bc854d8c5f85'

# %%
json_data = requests.get(api_endpoint).json()

# %%
cryptodata = json_data ['data']

# %%
for currency in cryptodata:
    curr_name = currency['name']
    curr_price = currency['quote']['USD']['price']
    curr_change_1h = currency['quote']['USD']['percent_change_1h']
    curr_change_24h = currency['quote']['USD']['percent_change_24h']
    curr_change_7d = currency['quote']['USD']['percent_change_7d']
    tableobj.add_row([curr_name, curr_price, curr_change_1h, curr_change_24h, curr_change_7d])

# %%
tableobj.field_names = ['Currency name', 'Currency Price', 'Currency 1h Change', 'Currency 24h Change', 'Currency 7d Change']

# %%
print(tableobj)
# Out:
# +-----------------------+------------------------+--------------------+---------------------+--------------------+
# |     Currency name     |     Currency Price     | Currency 1h Change | Currency 24h Change | Currency 7d Change |
# +-----------------------+------------------------+--------------------+---------------------+--------------------+
# |        Bitcoin        |   31748.132849902304   |    -1.91367469     |     -7.87126204     |    -17.74488041    |
# |        Ethereum       |   2331.8299622828577   |    -2.07502721     |     -7.86285804     |    -17.21373304    |
# |         Tether        |   0.9999255770294542   |    -0.01839962     |      0.01329648     |    -0.01799423     |
# |          BNB          |   311.58472931310064   |    -3.98854557     |     -12.96025544    |    -19.65512303    |
# |        USD Coin       |   0.9996328918836516   |     0.00778508     |     -0.04778964     |    -0.05146378     |
# |          XRP          |   0.5149702962065692   |     -2.2535091     |     -9.81560444     |    -15.57421155    |
# |         Solana        |   66.27242733159963    |    -5.20298453     |     -14.79358658    |    -23.81845013    |
# |        Cardano        |   0.628056792617521    |    -4.92991747     |     -15.5497559     |    -19.06141749    |
# |         Terra         |   53.68510642685237    |    -6.50922599     |     -17.91317057    |    -35.59520926    |
# |        TerraUSD       |   0.9831575560885796   |     -0.680041      |     -1.33897634     |    -1.80154259     |
# |      Binance USD      |   0.9996098131296739   |     -0.0581636     |     -0.19030488     |    -0.12609733     |
# |        Dogecoin       |  0.10799373238698615   |    -5.35860579     |     -14.16712192    |    -17.25962176    |
# |       Avalanche       |   45.23348188203775    |    -4.18418505     |     -13.58350217    |    -27.18346829    |
# |        Polkadot       |   11.073419105837488   |    -3.90524976     |     -17.81541888    |    -25.61563944    |
# |    Wrapped Bitcoin    |   31764.847886233543   |    -1.77091223     |     -7.88410006     |    -17.82438596    |
# |       Shiba Inu       |  1.49162448422501e-05  |    -7.47504843     |     -20.78731413    |    -27.71516064    |
# |          Dai          |   0.9983242489720173   |    -0.12338427     |     -0.13658615     |     -0.1372805     |
# |          TRON         |  0.07554323457507568   |    -2.47749098     |     -15.90629898    |    14.84797043     |
# |     NEAR Protocol     |   10.24012944402477    |    -6.40459543     |     -1.50659244     |    -9.98641446     |
# |        Polygon        |   0.8270476633615103   |    -4.95270961     |     -16.17950889    |    -23.03562397    |
# |        Litecoin       |   82.20775264460627    |    -3.01949603     |     -12.34732107    |    -17.51912339    |
# |         Cronos        |  0.22088410901273306   |    -3.39170965     |     -15.12065314    |    -21.65815203    |
# |      UNUS SED LEO     |    5.28553913348479    |     0.03110196     |     -1.76740962     |    -5.00800465     |
# |        Uniswap        |   6.421971389674457    |    -6.39999836     |     -11.11539149    |     -6.5254225     |
# |      Bitcoin Cash     |   231.1540187916342    |    -4.26840563     |     -12.55477184    |    -18.96339764    |
# |       FTX Token       |   31.62135876191642    |    -2.59855672     |     -7.39428073     |    -18.74036519    |
# |        Algorand       |   0.6258993948928708   |     -3.9414149     |     -14.82326687    |     5.1753982      |
# |       Chainlink       |    8.7922636240004     |    -3.44887736     |     -13.38317788    |    -20.90740347    |
# |         Cosmos        |   13.882508949465688   |    -4.12490135     |     -13.89141049    |    -22.1705699     |
# |        Stellar        |   0.1474772297300944   |    -3.12293848     |     -10.79618417    |    -15.06707296    |
# |         Monero        |   188.69197211205827   |    -4.21592444     |     -12.4432048     |    -10.48027366    |
# |    Ethereum Classic   |   23.714937210897702   |    -4.56081138     |     -11.46395968    |    -12.9183095     |
# |        VeChain        |  0.03962121715487698   |    -3.01597564     |     -12.38948687    |    -15.38713948    |
# |        ApeCoin        |   8.872810650304222    |    -12.0562233     |     -23.46286172    |    -39.91502879    |
# |   Internet Computer   |   10.45964651162331    |     -5.5188725     |     -13.45772719    |    -17.84688453    |
# |         Hedera        |  0.11214958879921155   |    -4.57985842     |     -12.35915691    |    -18.89112418    |
# |         Elrond        |   105.8062615868824    |    -1.36655084     |     -7.97639279     |    -15.62377243    |
# |        Filecoin       |   11.330156493452279   |    -5.94572958     |     -14.81394402    |    -22.65221653    |
# |      The Sandbox      |   1.7297226986570786   |    -5.23668175     |     -13.84954165    |    -17.54074899    |
# |      Decentraland     |   1.1364221056354784   |    -4.99630208     |     -16.20225437    |    -23.64086601    |
# |         Tezos         |    2.14907174724567    |    -4.91173229     |     -17.62339362    |    -13.04132536    |
# |     Theta Network     |   1.7795027007745612   |    -4.61519113     |     -16.15427461    |    -23.06754047    |
# |      PancakeSwap      |    5.92155116607931    |    -4.03528333     |     -15.19200849    |    -23.13551839    |
# |          EOS          |   1.7289368234426548   |    -5.50724478     |     -12.61219622    |    -17.18774427    |
# |     Axie Infinity     |   28.007118446031065   |     -4.2735329     |     -5.70079348     |    -6.77106928     |
# |       THORChain       |   4.847084776557313    |    -4.80945076     |     -16.43550458    |    -23.22436646    |
# |         Klaytn        |   0.5486152918680536   |    -3.05174688     |     -11.1623312     |    -22.15099701    |
# |         Fantom        |   0.5877222027505842   |    -4.84280634     |     -13.88149511    |    -24.48956592    |
# |         Waves         |   13.601864593520663   |    -2.29570945     |      4.04976834     |     8.45180872     |
# |          Aave         |   105.88245394502071   |    -7.27445003     |     -18.79341972    |    -26.06200661    |
# |         Helium        |   11.961161850149338   |    -4.11153991     |     -13.41565582    |    -14.14860969    |
# |     BitTorrent-New    | 1.4959199692820675e-06 |    -1.33015747     |     -7.47358579     |    -12.24955363    |
# |         Zcash         |   96.55928035400248    |    -5.07841582     |     -14.5992888     |    -19.30808482    |
# |      KuCoin Token     |   14.01290007082587    |    -2.37587561     |     -12.73553463    |    -22.27044133    |
# |          Flow         |   3.6332815023776326   |    -4.55046667     |     -14.94666709    |    -19.51669807    |
# |         STEPN         |   2.1641013983034396   |    -6.93809471     |     -18.0960633     |    -32.27153404    |
# |        TrueUSD        |   1.0002490151718508   |     0.01228873     |      0.02536852     |     0.11215978     |
# |      Huobi Token      |   8.054026446795561    |    -2.35500743     |     -8.03867267     |    -14.57641105    |
# |     Convex Finance    |   20.221895374890842   |    -1.04589927     |      -8.0435078     |    -10.93220701    |
# |       The Graph       |  0.25473576149768484   |    -6.12992283     |     -15.90180097    |    -16.61365098    |
# |       Bitcoin SV      |   62.44741678837363    |    -4.42271386     |     -11.0324781     |    -14.96136658    |
# |         eCash         | 6.097437379246736e-05  |    -4.11545745     |     -12.50703529    |    -15.41300008    |
# |          IOTA         |   0.4047782455873655   |    -4.03603932     |     -14.44570921    |    -22.80668157    |
# |         Maker         |   1060.7593113413648   |    -3.07589463     |     -12.20132022    |    -26.98499454    |
# |          Neo          |   14.014821856605469   |     -4.3952223     |     -13.29900726    |    -19.10303308    |
# |          Nexo         |   1.7024915238736875   |    -2.76485563     |     -8.28413299     |    -22.51199329    |
# |       Pax Dollar      |   0.9956221160726275   |    -0.31409523     |     -0.55813885     |    -0.68706601     |
# |    Curve DAO Token    |   2.0323752372710526   |    -3.08230683     |     -12.89550411    |     -1.8729044     |
# |      Neutrino USD     |   0.9786463335685205   |    -0.31046603     |     -0.23063884     |     0.43541315     |
# |          Celo         |   2.0689469163999425   |    -5.10599623     |     -9.15625407     |    -14.12125848    |
# |         Stacks        |   0.685680020138706    |    -3.92102468     |     -12.4983909     |    -26.71754899    |
# |         Quant         |   72.89146936844111    |    -4.08961371     |     -13.60531035    |    -24.13555079    |
# |        Zilliqa        |  0.06831762509925024   |    -3.97484708     |     -11.45018197    |    -1.56711289     |
# |          OKB          |   14.508488163273602   |    -1.96856326     |     -12.07893883    |    -23.15062208    |
# |         Chiliz        |  0.14084519338075713   |    -4.82147815     |     -14.85016664    |    -20.85665786    |
# |         Kusama        |   98.08682756160484    |    -4.42844173     |     -14.62571947    |    -24.71671095    |
# |          Dash         |   74.83062850898547    |    -3.06736255     |     -11.34146557    |    -15.74273866    |
# |          Gala         |   0.1124854256147588   |    -5.68146447     |     -15.99117145    |    -17.97644289    |
# |        Loopring       |   0.5779800802925261   |    -4.56762236     |     -15.00987195    |    -20.3817289     |
# |        Harmony        |  0.06242193312637224   |    -5.39367079     |     -14.44676517    |    -22.69106321    |
# |      XDC Network      |  0.059942887406414236  |    -0.12182903     |     -3.84049198     |    -2.17272753     |
# |       Enjin Coin      |   0.8222647022525751   |    -4.10598708     |     -15.94863662    |    -22.14607628    |
# |          Mina         |   1.4329987203415353   |    -4.53386584     |     -13.63440023    |    -21.21559633    |
# | Basic Attention Token |   0.4711881196395754   |    -3.97359995     |     -14.72363851    |    -19.13295542    |
# |        Lido DAO       |   2.1751569249777023   |     -6.050165      |     -11.51226632    |    -23.10779052    |
# |        PAX Gold       |   1858.8590174279523   |     0.03098186     |     -1.50919375     |    -0.80627661     |
# |          Amp          |  0.014467396672843386  |    -9.16703403     |     -18.83502276    |    -23.32525622    |
# |         Decred        |   43.300938854759536   |    -4.13233075     |     -13.64402727    |    -23.14704876    |
# |          NEM          |  0.06557522480321455   |     -7.094866      |     -16.52473005    |    -26.78456095    |
# |          Holo         | 0.0034005672929566496  |     -5.3245533     |     -12.00664469    |    -15.6646846     |
# |        Compound       |    84.5267357430029    |    -5.11655043     |     -15.33484346    |    -19.08405812    |
# |        Arweave        |   16.93190011550775    |    -6.63376197     |     -16.84714784    |    -29.39917484    |
# |          Kava         |   2.9232733578571017   |    -5.14781344     |     -16.70365937    |    -28.22189668    |
# |     1inch Network     |   1.295135352766315    |    -0.29050596     |     -0.18266404     |    10.63923338     |
# |          ICON         |   0.5732225190987185   |    -3.36630342     |     -8.61514953     |    -8.68738108     |
# |       Theta Fuel      |  0.09703901878437353   |    -4.06717302     |     -14.01688701    |    -26.73032927    |
# |         Gnosis        |   258.17379728734784   |    -1.68514403     |     -7.23423598     |    -18.22168986    |
# |     yearn.finance     |   13348.204838578942   |    -9.18840909     |     -16.17694382    |    -21.45784115    |
# |         Kadena        |   2.8439112553074963   |    -4.31204294     |     -10.08299201    |    -24.81502648    |
# |         Secret        |   2.877858285929056    |    -1.86088346     |     -11.58495117    |    -24.59296277    |
# +-----------------------+------------------------+--------------------+---------------------+--------------------+

# %%
table_txt=tableobj.get_string()
with open ('output.txt', 'w') as file:
    file.write(table_txt)

# %%
requests.get(api_endpoint).json()
# Out:
# {'status': {'timestamp': '2022-05-09T17:08:38.573Z',
#   'error_code': 0,
#   'error_message': None,
#   'elapsed': 28,
#   'credit_count': 1,
#   'notice': None,
#   'total_count': 10138},
#  'data': [{'id': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'slug': 'bitcoin',
#    'num_market_pairs': 9414,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'store-of-value',
#     'state-channel',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures-portfolio',
#     'galaxy-digital-portfolio',
#     'huobi-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital-portfolio',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-portfolio'],
#    'max_supply': 21000000,
#    'circulating_supply': 19035212,
#    'total_supply': 19035212,
#    'platform': None,
#    'cmc_rank': 1,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:08:00.000Z',
#    'quote': {'USD': {'price': 31277.315320559617,
#      'volume_24h': 46746189860.99154,
#      'volume_change_24h': 36.4221,
#      'percent_change_1h': -3.40481889,
#      'percent_change_24h': -8.04544113,
#      'percent_change_7d': -18.77295955,
#      'percent_change_30d': -26.33095587,
#      'percent_change_60d': -20.06213626,
#      'percent_change_90d': -27.27368625,
#      'market_cap': 595370327917.7003,
#      'market_cap_dominance': 41.1626,
#      'fully_diluted_market_cap': 656823621731.75,
#      'last_updated': '2022-05-09T17:08:00.000Z'}}},
#   {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'num_market_pairs': 5699,
#    'date_added': '2015-08-07T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'smart-contracts',
#     'ethereum-ecosystem',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'dcg-portfolio',
#     'dragonfly-capital-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'framework-ventures-portfolio',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'huobi-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     '1confirmation-portfolio',
#     'winklevoss-capital-portfolio',
#     'usv-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'multicoin-capital-portfolio',
#     'paradigm-portfolio',
#     'injective-ecosystem',
#     'bnb-chain'],
#    'max_supply': None,
#    'circulating_supply': 120710460.3115,
#    'total_supply': 120710460.3115,
#    'platform': None,
#    'cmc_rank': 2,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 2291.7520087342423,
#      'volume_24h': 28015283063.752472,
#      'volume_change_24h': 40.3924,
#      'percent_change_1h': -3.50000174,
#      'percent_change_24h': -8.74072665,
#      'percent_change_7d': -18.23719772,
#      'percent_change_30d': -28.82478274,
#      'percent_change_60d': -11.62511873,
#      'percent_change_90d': -24.73166764,
#      'market_cap': 276638439894.1152,
#      'market_cap_dominance': 19.1262,
#      'fully_diluted_market_cap': 276638439894.12,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 825,
#    'name': 'Tether',
#    'symbol': 'USDT',
#    'slug': 'tether',
#    'num_market_pairs': 33094,
#    'date_added': '2015-02-25T00:00:00.000Z',
#    'tags': ['payments',
#     'stablecoin',
#     'asset-backed-stablecoin',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'arbitrum-ecosytem',
#     'moonriver-ecosystem',
#     'injective-ecosystem',
#     'bnb-chain',
#     'usd-stablecoin'],
#    'max_supply': None,
#    'circulating_supply': 83217377094.91782,
#    'total_supply': 85713951814.94934,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'},
#    'cmc_rank': 3,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 1.0000078656088123,
#      'volume_24h': 90698056793.01823,
#      'volume_change_24h': 16.7167,
#      'percent_change_1h': -0.00648294,
#      'percent_change_24h': 0.01890286,
#      'percent_change_7d': -0.00513125,
#      'percent_change_30d': -0.03527258,
#      'percent_change_60d': -0.04363593,
#      'percent_change_90d': -0.06907826,
#      'market_cap': 83218031650.25243,
#      'market_cap_dominance': 5.766,
#      'fully_diluted_market_cap': 85714626007.36,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 1839,
#    'name': 'BNB',
#    'symbol': 'BNB',
#    'slug': 'bnb',
#    'num_market_pairs': 838,
#    'date_added': '2017-07-25T00:00:00.000Z',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'payments',
#     'smart-contracts',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio',
#     'moonriver-ecosystem',
#     'bnb-chain'],
#    'max_supply': 165116760,
#    'circulating_supply': 163276974.63,
#    'total_supply': 163276974.63,
#    'platform': None,
#    'cmc_rank': 4,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 309.6736957332453,
#      'volume_24h': 2330353885.472119,
#      'volume_change_24h': 24.6274,
#      'percent_change_1h': -4.2484657,
#      'percent_change_24h': -12.39059268,
#      'percent_change_7d': -19.89303171,
#      'percent_change_30d': -26.64424759,
#      'percent_change_60d': -15.54734065,
#      'percent_change_90d': -25.68453091,
#      'market_cap': 50562584161.81544,
#      'market_cap_dominance': 3.4951,
#      'fully_diluted_market_cap': 51132317296.7,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 3408,
#    'name': 'USD Coin',
#    'symbol': 'USDC',
#    'slug': 'usd-coin',
#    'num_market_pairs': 3911,
#    'date_added': '2018-10-08T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'stablecoin',
#     'asset-backed-stablecoin',
#     'fantom-ecosystem',
#     'arbitrum-ecosytem',
#     'moonriver-ecosystem',
#     'bnb-chain',
#     'usd-stablecoin'],
#    'max_supply': None,
#    'circulating_supply': 48728082001.25107,
#    'total_supply': 48728082001.25107,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#    'cmc_rank': 5,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 0.9995659614503696,
#      'volume_24h': 6542976518.351715,
#      'volume_change_24h': 19.6633,
#      'percent_change_1h': -0.01325982,
#      'percent_change_24h': -0.03931406,
#      'percent_change_7d': -0.06238309,
#      'percent_change_30d': 0.00538954,
#      'percent_change_60d': -0.01396244,
#      'percent_change_90d': 0.03938189,
#      'market_cap': 48706932135.212975,
#      'market_cap_dominance': 3.3675,
#      'fully_diluted_market_cap': 48706932135.21,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 52,
#    'name': 'XRP',
#    'symbol': 'XRP',
#    'slug': 'xrp',
#    'num_market_pairs': 720,
#    'date_added': '2013-08-04T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'binance-chain',
#     'arrington-xrp-capital-portfolio',
#     'galaxy-digital-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio'],
#    'max_supply': 100000000000,
#    'circulating_supply': 48343101197,
#    'total_supply': 99989535142,
#    'platform': None,
#    'cmc_rank': 6,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:08:00.000Z',
#    'quote': {'USD': {'price': 0.5083463546465391,
#      'volume_24h': 2288024048.804851,
#      'volume_change_24h': 49.9309,
#      'percent_change_1h': -3.35734958,
#      'percent_change_24h': -10.13906207,
#      'percent_change_7d': -16.40827907,
#      'percent_change_30d': -32.98528628,
#      'percent_change_60d': -30.3752797,
#      'percent_change_90d': -37.42256785,
#      'market_cap': 24575039265.80369,
#      'market_cap_dominance': 1.6991,
#      'fully_diluted_market_cap': 50834635464.65,
#      'last_updated': '2022-05-09T17:08:00.000Z'}}},
#   {'id': 5426,
#    'name': 'Solana',
#    'symbol': 'SOL',
#    'slug': 'solana',
#    'num_market_pairs': 307,
#    'date_added': '2020-04-10T00:00:00.000Z',
#    'tags': ['pos',
#     'platform',
#     'solana-ecosystem',
#     'cms-holdings-portfolio',
#     'kenetic-capital-portfolio',
#     'alameda-research-portfolio',
#     'multicoin-capital-portfolio',
#     'okex-blockdream-ventures-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 336622623.2903076,
#    'total_supply': 511616946.142289,
#    'platform': None,
#    'cmc_rank': 7,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 65.91295364338687,
#      'volume_24h': 2004527665.184934,
#      'volume_change_24h': 45.3281,
#      'percent_change_1h': -5.33629278,
#      'percent_change_24h': -14.08675435,
#      'percent_change_7d': -23.5998076,
#      'percent_change_30d': -40.21066782,
#      'percent_change_60d': -19.71473773,
#      'percent_change_90d': -40.63667276,
#      'market_cap': 22187791364.249325,
#      'market_cap_dominance': 1.5357,
#      'fully_diluted_market_cap': 33722184054.25,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 2010,
#    'name': 'Cardano',
#    'symbol': 'ADA',
#    'slug': 'cardano',
#    'num_market_pairs': 436,
#    'date_added': '2017-10-01T00:00:00.000Z',
#    'tags': ['mineable',
#     'dpos',
#     'pos',
#     'platform',
#     'research',
#     'smart-contracts',
#     'staking',
#     'cardano-ecosystem',
#     'cardano',
#     'bnb-chain'],
#    'max_supply': 45000000000,
#    'circulating_supply': 33752565071.288,
#    'total_supply': 34395513302.218,
#    'platform': None,
#    'cmc_rank': 8,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 0.6213206892910204,
#      'volume_24h': 1842240672.6453266,
#      'volume_change_24h': 77.9811,
#      'percent_change_1h': -5.58366741,
#      'percent_change_24h': -15.54955231,
#      'percent_change_7d': -19.77500853,
#      'percent_change_30d': -39.59013295,
#      'percent_change_60d': -22.44334743,
#      'percent_change_90d': -45.84873412,
#      'market_cap': 20971166995.43268,
#      'market_cap_dominance': 1.4496,
#      'fully_diluted_market_cap': 27959431018.1,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 7129,
#    'name': 'TerraUSD',
#    'symbol': 'UST',
#    'slug': 'terrausd',
#    'num_market_pairs': 538,
#    'date_added': '2020-09-21T00:00:00.000Z',
#    'tags': ['cosmos-ecosystem',
#     'stablecoin',
#     'terra-ecosystem',
#     'injective-ecosystem',
#     'bnb-chain',
#     'usd-stablecoin'],
#    'max_supply': None,
#    'circulating_supply': 18670928750.550613,
#    'total_supply': 18671496879.500557,
#    'platform': None,
#    'cmc_rank': 9,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 0.9814156831008207,
#      'volume_24h': 1393179047.1378603,
#      'volume_change_24h': -47.5223,
#      'percent_change_1h': -0.76574497,
#      'percent_change_24h': -1.54213016,
#      'percent_change_7d': -1.72480765,
#      'percent_change_30d': -1.88877195,
#      'percent_change_60d': -2.4091027,
#      'percent_change_90d': -2.00438856,
#      'market_cap': 18323942293.848385,
#      'market_cap_dominance': 1.2666,
#      'fully_diluted_market_cap': 18324499864.51,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 4172,
#    'name': 'Terra',
#    'symbol': 'LUNA',
#    'slug': 'terra-luna',
#    'num_market_pairs': 236,
#    'date_added': '2019-07-26T00:00:00.000Z',
#    'tags': ['cosmos-ecosystem',
#     'store-of-value',
#     'defi',
#     'payments',
#     'coinbase-ventures-portfolio',
#     'binance-labs-portfolio',
#     'solana-ecosystem',
#     'arrington-xrp-capital-portfolio',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'huobi-capital-portfolio',
#     'pantera-capital-portfolio',
#     'terra-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 343798231.3424571,
#    'total_supply': 726489951.668509,
#    'platform': None,
#    'cmc_rank': 10,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:08:00.000Z',
#    'quote': {'USD': {'price': 52.91109044913102,
#      'volume_24h': 4442830811.972248,
#      'volume_change_24h': -16.7133,
#      'percent_change_1h': -7.02068184,
#      'percent_change_24h': -16.53139179,
#      'percent_change_7d': -36.01272327,
#      'percent_change_30d': -43.50663459,
#      'percent_change_60d': -47.89537423,
#      'percent_change_90d': -4.50729018,
#      'market_cap': 18190739314.81202,
#      'market_cap_dominance': 1.2577,
#      'fully_diluted_market_cap': 38439375543.12,
#      'last_updated': '2022-05-09T17:08:00.000Z'}}},
#   {'id': 4687,
#    'name': 'Binance USD',
#    'symbol': 'BUSD',
#    'slug': 'binance-usd',
#    'num_market_pairs': 3659,
#    'date_added': '2019-09-20T00:00:00.000Z',
#    'tags': ['stablecoin',
#     'asset-backed-stablecoin',
#     'binance-chain',
#     'harmony-ecosystem',
#     'moonriver-ecosystem',
#     'bnb-chain',
#     'usd-stablecoin'],
#    'max_supply': None,
#    'circulating_supply': 17326002878.659256,
#    'total_supply': 17326002878.659256,
#    'platform': {'id': 1839,
#     'name': 'BNB Beacon Chain (BEP2)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': 'BUSD-BD1'},
#    'cmc_rank': 11,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 0.9994603522063322,
#      'volume_24h': 6194331839.413864,
#      'volume_change_24h': -52.5263,
#      'percent_change_1h': 0.02328692,
#      'percent_change_24h': -0.16609722,
#      'percent_change_7d': -0.11480768,
#      'percent_change_30d': 0.01912573,
#      'percent_change_60d': -0.12289479,
#      'percent_change_90d': -0.09667253,
#      'market_cap': 17316652939.432705,
#      'market_cap_dominance': 1.1972,
#      'fully_diluted_market_cap': 17316652939.43,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 74,
#    'name': 'Dogecoin',
#    'symbol': 'DOGE',
#    'slug': 'dogecoin',
#    'num_market_pairs': 472,
#    'date_added': '2013-12-15T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'scrypt',
#     'medium-of-exchange',
#     'memes',
#     'payments',
#     'doggone-doggerel',
#     'bnb-chain'],
#    'max_supply': None,
#    'circulating_supply': 132670764299.89409,
#    'total_supply': 132670764299.89409,
#    'platform': None,
#    'cmc_rank': 12,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:08:00.000Z',
#    'quote': {'USD': {'price': 0.10867372640434367,
#      'volume_24h': 1044051334.1326802,
#      'volume_change_24h': 40.0174,
#      'percent_change_1h': -4.65700417,
#      'percent_change_24h': -12.73286115,
#      'percent_change_7d': -16.45561327,
#      'percent_change_30d': -24.2287658,
#      'percent_change_60d': -6.96735357,
#      'percent_change_90d': -29.48419813,
#      'market_cap': 14417826341.381855,
#      'market_cap_dominance': 0.9966,
#      'fully_diluted_market_cap': 14417826341.38,
#      'last_updated': '2022-05-09T17:08:00.000Z'}}},
#   {'id': 5805,
#    'name': 'Avalanche',
#    'symbol': 'AVAX',
#    'slug': 'avalanche',
#    'num_market_pairs': 246,
#    'date_added': '2020-07-13T00:00:00.000Z',
#    'tags': ['defi',
#     'smart-contracts',
#     'polychain-capital-portfolio',
#     'avalanche-ecosystem',
#     'cms-holdings-portfolio',
#     'dragonfly-capital-portfolio',
#     'moonriver-ecosystem',
#     'injective-ecosystem',
#     'bnb-chain'],
#    'max_supply': None,
#    'circulating_supply': 268982695.00113493,
#    'total_supply': 395891289.9134107,
#    'platform': None,
#    'cmc_rank': 13,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 44.548102867328865,
#      'volume_24h': 985729950.4379199,
#      'volume_change_24h': 26.7296,
#      'percent_change_1h': -5.72514473,
#      'percent_change_24h': -13.52647735,
#      'percent_change_7d': -27.33082926,
#      'percent_change_30d': -46.44222887,
#      'percent_change_60d': -38.52785074,
#      'percent_change_90d': -47.09053041,
#      'market_cap': 11982668766.441904,
#      'market_cap_dominance': 0.8285,
#      'fully_diluted_market_cap': 17636205907.34,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 6636,
#    'name': 'Polkadot',
#    'symbol': 'DOT',
#    'slug': 'polkadot-new',
#    'num_market_pairs': 338,
#    'date_added': '2020-08-19T00:00:00.000Z',
#    'tags': ['substrate',
#     'polkadot',
#     'binance-chain',
#     'polkadot-ecosystem',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'arrington-xrp-capital-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'cms-holdings-portfolio',
#     'coinfund-portfolio',
#     'fabric-ventures-portfolio',
#     'fenbushi-capital-portfolio',
#     'hashkey-capital-portfolio',
#     'kenetic-capital-portfolio',
#     '1confirmation-portfolio',
#     'placeholder-ventures-portfolio',
#     'pantera-capital-portfolio',
#     'exnetwork-capital-portfolio',
#     'web3',
#     'spartan-group',
#     'injective-ecosystem',
#     'bnb-chain'],
#    'max_supply': None,
#    'circulating_supply': 987579314.957085,
#    'total_supply': 1103303471.382273,
#    'platform': None,
#    'cmc_rank': 14,
#    'self_reported_circulating_supply': 904869778,
#    'self_reported_market_cap': 9977975215.313747,
#    'last_updated': '2022-05-09T17:08:00.000Z',
#    'quote': {'USD': {'price': 11.026973668374355,
#      'volume_24h': 1134343391.395907,
#      'volume_change_24h': 53.6533,
#      'percent_change_1h': -3.95676716,
#      'percent_change_24h': -16.4938067,
#      'percent_change_7d': -25.56269229,
#      'percent_change_30d': -43.54010447,
#      'percent_change_60d': -35.1710166,
#      'percent_change_90d': -48.03453097,
#      'market_cap': 10890011101.46296,
#      'market_cap_dominance': 0.7529,
#      'fully_diluted_market_cap': 12166098327.16,
#      'last_updated': '2022-05-09T17:08:00.000Z'}}},
#   {'id': 3717,
#    'name': 'Wrapped Bitcoin',
#    'symbol': 'WBTC',
#    'slug': 'wrapped-bitcoin',
#    'num_market_pairs': 423,
#    'date_added': '2019-01-30T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'defi',
#     'wrapped-tokens',
#     'fantom-ecosystem',
#     'arbitrum-ecosytem',
#     'moonriver-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 283905.03000986,
#    'total_supply': 283905.03000986,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'},
#    'cmc_rank': 15,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 31457.2761141093,
#      'volume_24h': 462977171.0681398,
#      'volume_change_24h': 24.433,
#      'percent_change_1h': -2.57116758,
#      'percent_change_24h': -7.78669993,
#      'percent_change_7d': -18.25617799,
#      'percent_change_30d': -25.91502384,
#      'percent_change_60d': -19.65739941,
#      'percent_change_90d': -27.12580646,
#      'market_cap': 8930878919.204653,
#      'market_cap_dominance': 0.6175,
#      'fully_diluted_market_cap': 8930878919.2,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 5994,
#    'name': 'Shiba Inu',
#    'symbol': 'SHIB',
#    'slug': 'shiba-inu',
#    'num_market_pairs': 347,
#    'date_added': '2020-08-01T00:00:00.000Z',
#    'tags': ['memes', 'ethereum-ecosystem', 'doggone-doggerel'],
#    'max_supply': None,
#    'circulating_supply': 549063278876301.94,
#    'total_supply': 589735030408322.8,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#    'cmc_rank': 16,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 1.504817800672083e-05,
#      'volume_24h': 1058843215.4795251,
#      'volume_change_24h': 92.7408,
#      'percent_change_1h': -5.98721036,
#      'percent_change_24h': -19.16535016,
#      'percent_change_7d': -26.44359861,
#      'percent_change_30d': -37.41353592,
#      'percent_change_60d': -33.41644286,
#      'percent_change_90d': -49.69247783,
#      'market_cap': 8262401957.484392,
#      'market_cap_dominance': 0.5712,
#      'fully_diluted_market_cap': 8874437714.38,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 4943,
#    'name': 'Dai',
#    'symbol': 'DAI',
#    'slug': 'multi-collateral-dai',
#    'num_market_pairs': 946,
#    'date_added': '2019-11-22T00:00:00.000Z',
#    'tags': ['defi',
#     'stablecoin',
#     'ethereum-ecosystem',
#     'avalanche-ecosystem',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'arbitrum-ecosytem',
#     'harmony-ecosystem',
#     'moonriver-ecosystem',
#     'bnb-chain',
#     'usd-stablecoin'],
#    'max_supply': None,
#    'circulating_supply': 7724899124.863265,
#    'total_supply': 7724899124.863265,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6b175474e89094c44da98b954eedeac495271d0f'},
#    'cmc_rank': 17,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 0.9987636099431652,
#      'volume_24h': 559951046.1391438,
#      'volume_change_24h': 30.6793,
#      'percent_change_1h': -0.02632542,
#      'percent_change_24h': -0.06055603,
#      'percent_change_7d': -0.08888246,
#      'percent_change_30d': -0.09552852,
#      'percent_change_60d': -0.1276986,
#      'percent_change_90d': 0.03259172,
#      'market_cap': 7715348136.395232,
#      'market_cap_dominance': 0.5334,
#      'fully_diluted_market_cap': 7715348136.4,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 1958,
#    'name': 'TRON',
#    'symbol': 'TRX',
#    'slug': 'tron',
#    'num_market_pairs': 600,
#    'date_added': '2017-09-13T00:00:00.000Z',
#    'tags': ['media', 'payments', 'tron-ecosystem', 'bnb-chain'],
#    'max_supply': None,
#    'circulating_supply': 98390047231.32124,
#    'total_supply': 98390056530.3156,
#    'platform': None,
#    'cmc_rank': 18,
#    'self_reported_circulating_supply': 71659659264,
#    'self_reported_market_cap': 5466101681.798555,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 0.0762786446089702,
#      'volume_24h': 2657800897.9693184,
#      'volume_change_24h': -11.5692,
#      'percent_change_1h': -1.346477,
#      'percent_change_24h': -13.428437,
#      'percent_change_7d': 16.95653849,
#      'percent_change_30d': 21.96424533,
#      'percent_change_60d': 28.57399072,
#      'percent_change_90d': 13.73821919,
#      'market_cap': 7505059445.817745,
#      'market_cap_dominance': 0.5188,
#      'fully_diluted_market_cap': 7505060155.13,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 6535,
#    'name': 'NEAR Protocol',
#    'symbol': 'NEAR',
#    'slug': 'near-protocol',
#    'num_market_pairs': 138,
#    'date_added': '2020-08-11T00:00:00.000Z',
#    'tags': ['platform',
#     'staking',
#     'coinbase-ventures-portfolio',
#     'arrington-xrp-capital-portfolio',
#     'coinfund-portfolio',
#     'electric-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'kenetic-capital-portfolio',
#     'near-protocol-ecosystem',
#     'injective-ecosystem',
#     'bnb-chain'],
#    'max_supply': 1000000000,
#    'circulating_supply': 680330254,
#    'total_supply': 1000000000,
#    'platform': None,
#    'cmc_rank': 19,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:08:00.000Z',
#    'quote': {'USD': {'price': 10.242563854311667,
#      'volume_24h': 1373405420.0471811,
#      'volume_change_24h': 97.7043,
#      'percent_change_1h': -5.13429238,
#      'percent_change_24h': 0.75027802,
#      'percent_change_7d': -9.95917286,
#      'percent_change_30d': -37.1648491,
#      'percent_change_60d': -7.34434073,
#      'percent_change_90d': -16.69640398,
#      'market_cap': 6968326068.615076,
#      'market_cap_dominance': 0.4854,
#      'fully_diluted_market_cap': 10242563854.31,
#      'last_updated': '2022-05-09T17:08:00.000Z'}}},
#   {'id': 3890,
#    'name': 'Polygon',
#    'symbol': 'MATIC',
#    'slug': 'polygon',
#    'num_market_pairs': 382,
#    'date_added': '2019-04-28T00:00:00.000Z',
#    'tags': ['platform',
#     'enterprise-solutions',
#     'scaling',
#     'state-channel',
#     'coinbase-ventures-portfolio',
#     'binance-launchpad',
#     'binance-labs-portfolio',
#     'polygon-ecosystem',
#     'moonriver-ecosystem',
#     'injective-ecosystem',
#     'bnb-chain'],
#    'max_supply': 10000000000,
#    'circulating_supply': 7848866566.62,
#    'total_supply': 10000000000,
#    'platform': None,
#    'cmc_rank': 20,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 0.8198042072974471,
#      'volume_24h': 736113767.1573796,
#      'volume_change_24h': 19.3496,
#      'percent_change_1h': -5.08821953,
#      'percent_change_24h': -15.92307915,
#      'percent_change_7d': -23.13372542,
#      'percent_change_30d': -43.2033441,
#      'percent_change_60d': -42.23729975,
#      'percent_change_90d': -56.30165094,
#      'market_cap': 6434533833.831344,
#      'market_cap_dominance': 0.4454,
#      'fully_diluted_market_cap': 8198042072.97,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 2,
#    'name': 'Litecoin',
#    'symbol': 'LTC',
#    'slug': 'litecoin',
#    'num_market_pairs': 768,
#    'date_added': '2013-04-28T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'scrypt',
#     'medium-of-exchange',
#     'binance-chain',
#     'bnb-chain'],
#    'max_supply': 84000000,
#    'circulating_supply': 70249556.27791464,
#    'total_supply': 84000000,
#    'platform': None,
#    'cmc_rank': 21,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:08:00.000Z',
#    'quote': {'USD': {'price': 81.27622368264987,
#      'volume_24h': 948863806.2112088,
#      'volume_change_24h': 41.4018,
#      'percent_change_1h': -3.95383272,
#      'percent_change_24h': -12.4257292,
#      'percent_change_7d': -18.22561123,
#      'percent_change_30d': -26.9992092,
#      'percent_change_60d': -20.48206709,
#      'percent_change_90d': -38.08142053,
#      'market_cap': 5709618649.650691,
#      'market_cap_dominance': 0.3947,
#      'fully_diluted_market_cap': 6827202789.34,
#      'last_updated': '2022-05-09T17:08:00.000Z'}}},
#   {'id': 3635,
#    'name': 'Cronos',
#    'symbol': 'CRO',
#    'slug': 'cronos',
#    'num_market_pairs': 135,
#    'date_added': '2018-12-14T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'cosmos-ecosystem',
#     'centralized-exchange',
#     'mobile',
#     'payments'],
#    'max_supply': 30263013692,
#    'circulating_supply': 25263013692,
#    'total_supply': 30263013692,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#    'cmc_rank': 22,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 0.21720473405367377,
#      'volume_24h': 68418681.60951951,
#      'volume_change_24h': 36.1472,
#      'percent_change_1h': -4.59975297,
#      'percent_change_24h': -15.63632822,
#      'percent_change_7d': -21.64713798,
#      'percent_change_30d': -50.31381837,
#      'percent_change_60d': -43.71460581,
#      'percent_change_90d': -54.94122424,
#      'market_cap': 5487246170.365179,
#      'market_cap_dominance': 0.3794,
#      'fully_diluted_market_cap': 6573269840.63,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 3957,
#    'name': 'UNUS SED LEO',
#    'symbol': 'LEO',
#    'slug': 'unus-sed-leo',
#    'num_market_pairs': 19,
#    'date_added': '2019-05-21T00:00:00.000Z',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'discount-token',
#     'payments',
#     'kenetic-capital-portfolio',
#     'alameda-research-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 953954130,
#    'total_supply': 985239504,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3'},
#    'cmc_rank': 23,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 5.288811053558726,
#      'volume_24h': 7453511.00013426,
#      'volume_change_24h': 19.6051,
#      'percent_change_1h': -0.19654628,
#      'percent_change_24h': -1.62721787,
#      'percent_change_7d': -4.92319606,
#      'percent_change_30d': -9.73805451,
#      'percent_change_60d': -9.17236303,
#      'percent_change_90d': -27.04461297,
#      'market_cap': 5045283147.331998,
#      'market_cap_dominance': 0.3488,
#      'fully_diluted_market_cap': 5210745579.16,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 7083,
#    'name': 'Uniswap',
#    'symbol': 'UNI',
#    'slug': 'uniswap',
#    'num_market_pairs': 362,
#    'date_added': '2020-09-17T00:00:00.000Z',
#    'tags': ['decentralized-exchange',
#     'defi',
#     'dao',
#     'yield-farming',
#     'amm',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'governance',
#     'blockchain-capital-portfolio',
#     'defiance-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio',
#     'parafi-capital',
#     'paradigm-portfolio',
#     'arbitrum-ecosytem',
#     'injective-ecosystem',
#     'bnb-chain'],
#    'max_supply': 1000000000,
#    'circulating_supply': 690676383.0032357,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#    'cmc_rank': 24,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 6.390546882441863,
#      'volume_24h': 279371492.24440527,
#      'volume_change_24h': 37.728,
#      'percent_change_1h': -5.20674807,
#      'percent_change_24h': -10.58005569,
#      'percent_change_7d': -6.55910144,
#      'percent_change_30d': -35.50406597,
#      'percent_change_60d': -26.09014565,
#      'percent_change_90d': -44.90205747,
#      'market_cap': 4413799806.17755,
#      'market_cap_dominance': 0.3052,
#      'fully_diluted_market_cap': 6390546882.44,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 1831,
#    'name': 'Bitcoin Cash',
#    'symbol': 'BCH',
#    'slug': 'bitcoin-cash',
#    'num_market_pairs': 592,
#    'date_added': '2017-07-23T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'sha-256',
#     'marketplace',
#     'medium-of-exchange',
#     'store-of-value',
#     'enterprise-solutions',
#     'payments',
#     'binance-chain',
#     'bnb-chain'],
#    'max_supply': 21000000,
#    'circulating_supply': 19058787.5,
#    'total_supply': 19058787.5,
#    'platform': None,
#    'cmc_rank': 25,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 229.2525326199227,
#      'volume_24h': 3910943595.1222897,
#      'volume_change_24h': -0.4469,
#      'percent_change_1h': -4.06740114,
#      'percent_change_24h': -12.51042693,
#      'percent_change_7d': -19.32967542,
#      'percent_change_30d': -29.33709581,
#      'percent_change_60d': -20.20875003,
#      'percent_change_90d': -30.06663333,
#      'market_cap': 4369275303.039925,
#      'market_cap_dominance': 0.302,
#      'fully_diluted_market_cap': 4814303185.02,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 4195,
#    'name': 'FTX Token',
#    'symbol': 'FTT',
#    'slug': 'ftx-token',
#    'num_market_pairs': 123,
#    'date_added': '2019-07-31T00:00:00.000Z',
#    'tags': ['marketplace',
#     'centralized-exchange',
#     'derivatives',
#     'cms-holdings-portfolio',
#     'kenetic-capital-portfolio',
#     'alameda-research-portfolio',
#     'pantera-capital-portfolio',
#     'exnetwork-capital-portfolio'],
#    'max_supply': 352170015,
#    'circulating_supply': 136769342.51874372,
#    'total_supply': 332638678.5859715,
#    'platform': {'id': 1839,
#     'name': 'BNB Beacon Chain (BEP2)',
#     'symbol': 'BNB',
#     'slug': 'bnb',
#     'token_address': 'FTT-F11'},
#    'cmc_rank': 26,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:08:00.000Z',
#    'quote': {'USD': {'price': 31.26743706261405,
#      'volume_24h': 129103645.64306206,
#      'volume_change_24h': 102.0366,
#      'percent_change_1h': -3.6753913,
#      'percent_change_24h': -7.51211843,
#      'percent_change_7d': -19.3327634,
#      'percent_change_30d': -30.52904733,
#      'percent_change_60d': -22.81284151,
#      'percent_change_90d': -31.34531918,
#      'market_cap': 4276426809.299923,
#      'market_cap_dominance': 0.2957,
#      'fully_diluted_market_cap': 11011453779.35,
#      'last_updated': '2022-05-09T17:08:00.000Z'}}},
#   {'id': 4030,
#    'name': 'Algorand',
#    'symbol': 'ALGO',
#    'slug': 'algorand',
#    'num_market_pairs': 212,
#    'date_added': '2019-06-20T00:00:00.000Z',
#    'tags': ['pos',
#     'platform',
#     'research',
#     'smart-contracts',
#     'arrington-xrp-capital-portfolio',
#     'kenetic-capital-portfolio',
#     'usv-portfolio',
#     'multicoin-capital-portfolio',
#     'exnetwork-capital-portfolio'],
#    'max_supply': 10000000000,
#    'circulating_supply': 6809449311.155754,
#    'total_supply': 7217353415.678712,
#    'platform': None,
#    'cmc_rank': 27,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 0.6269998586896629,
#      'volume_24h': 525842477.4875706,
#      'volume_change_24h': -29.3402,
#      'percent_change_1h': -3.34332545,
#      'percent_change_24h': -13.8508405,
#      'percent_change_7d': 5.80448901,
#      'percent_change_30d': -19.31636744,
#      'percent_change_60d': -14.44622936,
#      'percent_change_90d': -37.04914109,
#      'market_cap': 4269523755.84908,
#      'market_cap_dominance': 0.2951,
#      'fully_diluted_market_cap': 6269998586.9,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 1975,
#    'name': 'Chainlink',
#    'symbol': 'LINK',
#    'slug': 'chainlink',
#    'num_market_pairs': 641,
#    'date_added': '2017-09-20T00:00:00.000Z',
#    'tags': ['platform',
#     'defi',
#     'oracles',
#     'smart-contracts',
#     'substrate',
#     'polkadot',
#     'polkadot-ecosystem',
#     'avalanche-ecosystem',
#     'solana-ecosystem',
#     'framework-ventures-portfolio',
#     'polygon-ecosystem',
#     'fantom-ecosystem',
#     'cardano-ecosystem',
#     'web3',
#     'near-protocol-ecosystem',
#     'arbitrum-ecosytem',
#     'cardano',
#     'injective-ecosystem',
#     'bnb-chain'],
#    'max_supply': 1000000000,
#    'circulating_supply': 467009549.5205637,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#    'cmc_rank': 28,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 8.687086805804773,
#      'volume_24h': 613917340.6205053,
#      'volume_change_24h': 41.5362,
#      'percent_change_1h': -4.37299109,
#      'percent_change_24h': -13.3421449,
#      'percent_change_7d': -21.4131724,
#      'percent_change_30d': -43.02860499,
#      'percent_change_60d': -34.3600024,
#      'percent_change_90d': -51.26890272,
#      'market_cap': 4056952495.8249197,
#      'market_cap_dominance': 0.2805,
#      'fully_diluted_market_cap': 8687086805.8,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 3794,
#    'name': 'Cosmos',
#    'symbol': 'ATOM',
#    'slug': 'cosmos',
#    'num_market_pairs': 275,
#    'date_added': '2019-03-14T00:00:00.000Z',
#    'tags': ['platform',
#     'cosmos-ecosystem',
#     'content-creation',
#     'interoperability',
#     'binance-chain',
#     'polychain-capital-portfolio',
#     'dragonfly-capital-portfolio',
#     'hashkey-capital-portfolio',
#     '1confirmation-portfolio',
#     'paradigm-portfolio',
#     'exnetwork-capital-portfolio',
#     'injective-ecosystem',
#     'bnb-chain'],
#    'max_supply': None,
#    'circulating_supply': 286370297,
#    'total_supply': 0,
#    'platform': None,
#    'cmc_rank': 29,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 13.886442744248829,
#      'volume_24h': 512483551.4574882,
#      'volume_change_24h': 10.4029,
#      'percent_change_1h': -4.12980768,
#      'percent_change_24h': -12.62879065,
#      'percent_change_7d': -21.50461773,
#      'percent_change_30d': -48.55982487,
#      'percent_change_60d': -50.36106859,
#      'percent_change_90d': -53.87650113,
#      'market_cap': 3976664732.944032,
#      'market_cap_dominance': 0.2755,
#      'fully_diluted_market_cap': 0,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 512,
#    'name': 'Stellar',
#    'symbol': 'XLM',
#    'slug': 'stellar',
#    'num_market_pairs': 421,
#    'date_added': '2014-08-05T00:00:00.000Z',
#    'tags': ['medium-of-exchange',
#     'enterprise-solutions',
#     'decentralized-exchange',
#     'smart-contracts',
#     'hashkey-capital-portfolio'],
#    'max_supply': 50001806812,
#    'circulating_supply': 24797748393.991756,
#    'total_supply': 50001787831.50056,
#    'platform': None,
#    'cmc_rank': 30,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:08:00.000Z',
#    'quote': {'USD': {'price': 0.1455568800376992,
#      'volume_24h': 304546824.0159955,
#      'volume_change_24h': 35.9082,
#      'percent_change_1h': -4.35391616,
#      'percent_change_24h': -10.97265653,
#      'percent_change_7d': -16.04462386,
#      'percent_change_30d': -28.36501472,
#      'percent_change_60d': -18.13192117,
#      'percent_change_90d': -38.07782478,
#      'market_cap': 3609482888.1893063,
#      'market_cap_dominance': 0.2495,
#      'fully_diluted_market_cap': 7278106995.8,
#      'last_updated': '2022-05-09T17:08:00.000Z'}}},
#   {'id': 328,
#    'name': 'Monero',
#    'symbol': 'XMR',
#    'slug': 'monero',
#    'num_market_pairs': 178,
#    'date_added': '2014-05-21T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'medium-of-exchange',
#     'privacy',
#     'ringct',
#     'boostvc-portfolio',
#     'electric-capital-portfolio',
#     'galaxy-digital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 18118815.44594654,
#    'total_supply': 18118815.44594654,
#    'platform': None,
#    'cmc_rank': 31,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:08:00.000Z',
#    'quote': {'USD': {'price': 187.9434667934912,
#      'volume_24h': 256761874.74289912,
#      'volume_change_24h': -1.8145,
#      'percent_change_1h': -4.04445826,
#      'percent_change_24h': -11.80443953,
#      'percent_change_7d': -10.68938616,
#      'percent_change_30d': -19.39356079,
#      'percent_change_60d': 10.3507327,
#      'percent_change_90d': 5.50612395,
#      'market_cap': 3405312989.102649,
#      'market_cap_dominance': 0.2354,
#      'fully_diluted_market_cap': 3405312989.1,
#      'last_updated': '2022-05-09T17:08:00.000Z'}}},
#   {'id': 1321,
#    'name': 'Ethereum Classic',
#    'symbol': 'ETC',
#    'slug': 'ethereum-classic',
#    'num_market_pairs': 304,
#    'date_added': '2016-07-24T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'ethash',
#     'platform',
#     'smart-contracts',
#     'dcg-portfolio',
#     'bnb-chain'],
#    'max_supply': 210700000,
#    'circulating_supply': 134683791.81491852,
#    'total_supply': 210700000,
#    'platform': None,
#    'cmc_rank': 32,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 23.455461660802136,
#      'volume_24h': 521966193.16166383,
#      'volume_change_24h': 21.0759,
#      'percent_change_1h': -4.93127404,
#      'percent_change_24h': -11.36956441,
#      'percent_change_7d': -13.52528659,
#      'percent_change_30d': -43.19264766,
#      'percent_change_60d': -11.28547524,
#      'percent_change_90d': -23.79720502,
#      'market_cap': 3159070515.246278,
#      'market_cap_dominance': 0.2183,
#      'fully_diluted_market_cap': 4942065771.93,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 3077,
#    'name': 'VeChain',
#    'symbol': 'VET',
#    'slug': 'vechain',
#    'num_market_pairs': 183,
#    'date_added': '2017-08-22T00:00:00.000Z',
#    'tags': ['logistics',
#     'data-provenance',
#     'iot',
#     'smart-contracts',
#     'fenbushi-capital-portfolio'],
#    'max_supply': 86712634466,
#    'circulating_supply': 64315576989,
#    'total_supply': 86712634466,
#    'platform': None,
#    'cmc_rank': 33,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 0.03926951912793485,
#      'volume_24h': 288472687.298521,
#      'volume_change_24h': 34.8729,
#      'percent_change_1h': -3.62849161,
#      'percent_change_24h': -11.97092932,
#      'percent_change_7d': -15.62551002,
#      'percent_change_30d': -39.80427552,
#      'percent_change_60d': -15.2787881,
#      'percent_change_90d': -37.39780719,
#      'market_cap': 2525641780.793702,
#      'market_cap_dominance': 0.1746,
#      'fully_diluted_market_cap': 3405163457.8,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 18876,
#    'name': 'ApeCoin',
#    'symbol': 'APE',
#    'slug': 'apecoin-ape',
#    'num_market_pairs': 136,
#    'date_added': '2022-03-17T12:26:36.000Z',
#    'tags': ['collectibles-nfts',
#     'content-creation',
#     'gaming',
#     'entertainment',
#     'dao',
#     'governance',
#     'metaverse',
#     'animoca-brands-portfolio'],
#    'max_supply': 1000000000,
#    'circulating_supply': 284843750,
#    'total_supply': 1000000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x4d224452801aced8b2f0aebe155379bb5d594381'},
#    'cmc_rank': 34,
#    'self_reported_circulating_supply': 284843750,
#    'self_reported_market_cap': 2518712117.4816346,
#    'last_updated': '2022-05-09T17:08:00.000Z',
#    'quote': {'USD': {'price': 8.842434202897675,
#      'volume_24h': 1006419593.2155741,
#      'volume_change_24h': 51.9125,
#      'percent_change_1h': -11.14911038,
#      'percent_change_24h': -21.34961733,
#      'percent_change_7d': -39.83591723,
#      'percent_change_30d': -17.94950529,
#      'percent_change_60d': 783.89282823,
#      'percent_change_90d': 783.89282823,
#      'market_cap': 2518712117.4816346,
#      'market_cap_dominance': 0.1745,
#      'fully_diluted_market_cap': 8842434202.9,
#      'last_updated': '2022-05-09T17:08:00.000Z'}}},
#   {'id': 8916,
#    'name': 'Internet Computer',
#    'symbol': 'ICP',
#    'slug': 'internet-computer',
#    'num_market_pairs': 113,
#    'date_added': '2021-03-23T00:00:00.000Z',
#    'tags': ['platform',
#     'distributed-computing',
#     'polychain-capital-portfolio',
#     'exnetwork-capital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 226803468.1107057,
#    'total_supply': 481178757.23197085,
#    'platform': None,
#    'cmc_rank': 35,
#    'self_reported_circulating_supply': 226803223.44667637,
#    'self_reported_market_cap': 2339061844.973329,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 10.313177253070503,
#      'volume_24h': 221205222.4754982,
#      'volume_change_24h': 73.8868,
#      'percent_change_1h': -5.85211039,
#      'percent_change_24h': -13.17602032,
#      'percent_change_7d': -18.28518499,
#      'percent_change_30d': -42.75760386,
#      'percent_change_60d': -37.22873723,
#      'percent_change_90d': -53.84895479,
#      'market_cap': 2339064368.236831,
#      'market_cap_dominance': 0.1617,
#      'fully_diluted_market_cap': 4962481813.75,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 4642,
#    'name': 'Hedera',
#    'symbol': 'HBAR',
#    'slug': 'hedera',
#    'num_market_pairs': 98,
#    'date_added': '2019-09-17T00:00:00.000Z',
#    'tags': ['dag',
#     'marketplace',
#     'enterprise-solutions',
#     'payments',
#     'dcg-portfolio'],
#    'max_supply': 50000000000,
#    'circulating_supply': 20741406793.008232,
#    'total_supply': 50000000000,
#    'platform': None,
#    'cmc_rank': 36,
#    'self_reported_circulating_supply': 19389577881,
#    'self_reported_market_cap': 2156510249.7902083,
#    'last_updated': '2022-05-09T17:08:00.000Z',
#    'quote': {'USD': {'price': 0.11122007209364726,
#      'volume_24h': 62844315.30676777,
#      'volume_change_24h': 40.7808,
#      'percent_change_1h': -4.99410685,
#      'percent_change_24h': -11.97924404,
#      'percent_change_7d': -19.04881655,
#      'percent_change_30d': -46.9367392,
#      'percent_change_60d': -46.34406151,
#      'percent_change_90d': -54.34283342,
#      'market_cap': 2306860758.8420405,
#      'market_cap_dominance': 0.1595,
#      'fully_diluted_market_cap': 5561003604.68,
#      'last_updated': '2022-05-09T17:08:00.000Z'}}},
#   {'id': 6892,
#    'name': 'Elrond',
#    'symbol': 'EGLD',
#    'slug': 'elrond-egld',
#    'num_market_pairs': 94,
#    'date_added': '2020-09-04T00:00:00.000Z',
#    'tags': ['binance-launchpad',
#     'binance-labs-portfolio',
#     'electric-capital-portfolio',
#     'exnetwork-capital-portfolio',
#     'elrond-ecosystem',
#     'injective-ecosystem',
#     'bnb-chain'],
#    'max_supply': 31415926,
#    'circulating_supply': 21911492.87119072,
#    'total_supply': 23016298,
#    'platform': None,
#    'cmc_rank': 37,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 104.62993453553521,
#      'volume_24h': 104269967.39223194,
#      'volume_change_24h': 29.4936,
#      'percent_change_1h': -2.15218498,
#      'percent_change_24h': -7.76482255,
#      'percent_change_7d': -16.13585865,
#      'percent_change_30d': -36.66672037,
#      'percent_change_60d': -27.60455306,
#      'percent_change_90d': -38.46317135,
#      'market_cap': 2292598064.6885314,
#      'market_cap_dominance': 0.1584,
#      'fully_diluted_market_cap': 3287046280.75,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 2280,
#    'name': 'Filecoin',
#    'symbol': 'FIL',
#    'slug': 'filecoin',
#    'num_market_pairs': 201,
#    'date_added': '2017-12-13T00:00:00.000Z',
#    'tags': ['mineable',
#     'distributed-computing',
#     'filesharing',
#     'storage',
#     'polychain-capital-portfolio',
#     'blockchain-capital-portfolio',
#     'boostvc-portfolio',
#     'dcg-portfolio',
#     'hashkey-capital-portfolio',
#     'a16z-portfolio',
#     'winklevoss-capital-portfolio',
#     'pantera-capital-portfolio',
#     'web3',
#     'bnb-chain'],
#    'max_supply': None,
#    'circulating_supply': 200890317,
#    'total_supply': 200890317,
#    'platform': None,
#    'cmc_rank': 38,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:08:00.000Z',
#    'quote': {'USD': {'price': 11.276303784590779,
#      'volume_24h': 594142302.5192816,
#      'volume_change_24h': 13.173,
#      'percent_change_1h': -6.04154161,
#      'percent_change_24h': -14.05527883,
# ...
#      'fully_diluted_market_cap': 1315650086.11,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 1168,
#    'name': 'Decred',
#    'symbol': 'DCR',
#    'slug': 'decred',
#    'num_market_pairs': 57,
#    'date_added': '2016-02-10T00:00:00.000Z',
#    'tags': ['mineable',
#     'hybrid-pow-pos',
#     'blake256',
#     'medium-of-exchange',
#     'store-of-value',
#     'privacy',
#     'dao',
#     'placeholder-ventures-portfolio'],
#    'max_supply': 21000000,
#    'circulating_supply': 14003574.12383633,
#    'total_supply': 14003574.12383633,
#    'platform': None,
#    'cmc_rank': 88,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 42.68439933444439,
#      'volume_24h': 2890525.78345214,
#      'volume_change_24h': 0.4038,
#      'percent_change_1h': -5.19204426,
#      'percent_change_24h': -13.90234707,
#      'percent_change_7d': -24.05904945,
#      'percent_change_30d': -25.75731533,
#      'percent_change_60d': -20.46983975,
#      'percent_change_90d': -36.09567815,
#      'market_cap': 597734150.0113221,
#      'market_cap_dominance': 0.0414,
#      'fully_diluted_market_cap': 896372386.02,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 2682,
#    'name': 'Holo',
#    'symbol': 'HOT',
#    'slug': 'holo',
#    'num_market_pairs': 114,
#    'date_added': '2018-04-29T00:00:00.000Z',
#    'tags': ['platform', 'distributed-computing', 'filesharing', 'storage'],
#    'max_supply': None,
#    'circulating_supply': 173305412321.07236,
#    'total_supply': 177619433541.14133,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6c6ee5e31d828de241282b9606c8e98ea48526e2'},
#    'cmc_rank': 89,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 0.0033886213265670647,
#      'volume_24h': 50393590.13143588,
#      'volume_change_24h': 22.9032,
#      'percent_change_1h': -5.17506856,
#      'percent_change_24h': -11.03013812,
#      'percent_change_7d': -15.45365094,
#      'percent_change_30d': -35.82738724,
#      'percent_change_60d': -15.14283596,
#      'percent_change_90d': -37.9613126,
#      'market_cap': 587266416.2006843,
#      'market_cap_dominance': 0.0406,
#      'fully_diluted_market_cap': 601885000.51,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 873,
#    'name': 'NEM',
#    'symbol': 'XEM',
#    'slug': 'nem',
#    'num_market_pairs': 122,
#    'date_added': '2015-04-01T00:00:00.000Z',
#    'tags': ['poi',
#     'medium-of-exchange',
#     'payments',
#     'smart-contracts',
#     'fantom-ecosystem'],
#    'max_supply': 8999999999,
#    'circulating_supply': 8999999999,
#    'total_supply': 8999999999,
#    'platform': None,
#    'cmc_rank': 90,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 0.06494984783892584,
#      'volume_24h': 37023203.15183955,
#      'volume_change_24h': 97.6755,
#      'percent_change_1h': -7.70630056,
#      'percent_change_24h': -16.52667698,
#      'percent_change_7d': -27.28176749,
#      'percent_change_30d': -37.91247958,
#      'percent_change_60d': -31.99784527,
#      'percent_change_90d': -42.02089889,
#      'market_cap': 584548630.4853827,
#      'market_cap_dominance': 0.0404,
#      'fully_diluted_market_cap': 584548630.49,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 5692,
#    'name': 'Compound',
#    'symbol': 'COMP',
#    'slug': 'compound',
#    'num_market_pairs': 261,
#    'date_added': '2020-06-16T00:00:00.000Z',
#    'tags': ['defi',
#     'dao',
#     'yield-farming',
#     'polkadot-ecosystem',
#     'coinbase-ventures-portfolio',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'lending-borowing',
#     'dragonfly-capital-portfolio',
#     'alameda-research-portfolio',
#     'a16z-portfolio',
#     'pantera-capital-portfolio',
#     'paradigm-portfolio',
#     'bnb-chain'],
#    'max_supply': 10000000,
#    'circulating_supply': 6793329.73019251,
#    'total_supply': 10000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0xc00e94cb662c3520282e6f5717214004a7f26888'},
#    'cmc_rank': 91,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 83.82539812489638,
#      'volume_24h': 75778834.2302263,
#      'volume_change_24h': 25.8654,
#      'percent_change_1h': -5.48265198,
#      'percent_change_24h': -15.32384396,
#      'percent_change_7d': -19.32732377,
#      'percent_change_30d': -38.06540793,
#      'percent_change_60d': -17.71752686,
#      'percent_change_90d': -39.23978096,
#      'market_cap': 569453569.2270821,
#      'market_cap_dominance': 0.0394,
#      'fully_diluted_market_cap': 838253981.25,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 5632,
#    'name': 'Arweave',
#    'symbol': 'AR',
#    'slug': 'arweave',
#    'num_market_pairs': 55,
#    'date_added': '2020-05-27T00:00:00.000Z',
#    'tags': ['distributed-computing',
#     'filesharing',
#     'storage',
#     'coinbase-ventures-portfolio',
#     'solana-ecosystem',
#     'arrington-xrp-capital-portfolio',
#     'blockchain-capital-portfolio',
#     'a16z-portfolio',
#     'multicoin-capital-portfolio',
#     'web3'],
#    'max_supply': 66000000,
#    'circulating_supply': 33394701,
#    'total_supply': 63190435,
#    'platform': None,
#    'cmc_rank': 92,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 16.843361473123895,
#      'volume_24h': 46955797.65185434,
#      'volume_change_24h': 9.7185,
#      'percent_change_1h': -5.99287664,
#      'percent_change_24h': -16.08334005,
#      'percent_change_7d': -29.22421007,
#      'percent_change_30d': -50.79249036,
#      'percent_change_60d': -49.09015254,
#      'percent_change_90d': -52.97225161,
#      'market_cap': 562479020.229892,
#      'market_cap_dominance': 0.0389,
#      'fully_diluted_market_cap': 1111661857.23,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 4846,
#    'name': 'Kava',
#    'symbol': 'KAVA',
#    'slug': 'kava',
#    'num_market_pairs': 78,
#    'date_added': '2019-10-25T00:00:00.000Z',
#    'tags': ['cosmos-ecosystem',
#     'defi',
#     'binance-launchpad',
#     'binance-labs-portfolio',
#     'lending-borowing',
#     'arrington-xrp-capital-portfolio',
#     'framework-ventures-portfolio',
#     'hashkey-capital-portfolio',
#     'injective-ecosystem'],
#    'max_supply': None,
#    'circulating_supply': 188828769,
#    'total_supply': 173657543,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x0C356B7fD36a5357E5A017EF11887ba100C9AB76'},
#    'cmc_rank': 93,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 2.8933991662526566,
#      'volume_24h': 43550312.62210399,
#      'volume_change_24h': 7.3022,
#      'percent_change_1h': -5.38039361,
#      'percent_change_24h': -15.95303851,
#      'percent_change_7d': -28.6003691,
#      'percent_change_30d': -36.92507302,
#      'percent_change_60d': -5.9496146,
#      'percent_change_90d': -20.44022348,
#      'market_cap': 546357002.7891154,
#      'market_cap_dominance': 0.0378,
#      'fully_diluted_market_cap': 502460590.13,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 8104,
#    'name': '1inch Network',
#    'symbol': '1INCH',
#    'slug': '1inch',
#    'num_market_pairs': 227,
#    'date_added': '2020-12-25T00:00:00.000Z',
#    'tags': ['decentralized-exchange',
#     'defi',
#     'amm',
#     'binance-labs-portfolio',
#     'blockchain-capital-portfolio',
#     'dragonfly-capital-portfolio',
#     'fabric-ventures-portfolio',
#     'alameda-research-portfolio',
#     'parafi-capital',
#     'spartan-group',
#     'bnb-chain'],
#    'max_supply': None,
#    'circulating_supply': 415046890.03209734,
#    'total_supply': 1500000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x111111111117dc0aa78b770fa6a738034120c302'},
#    'cmc_rank': 94,
#    'self_reported_circulating_supply': 415047658.68990487,
#    'self_reported_market_cap': 537603363.5784599,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 1.2952810413999232,
#      'volume_24h': 115785398.69247976,
#      'volume_change_24h': 26.5125,
#      'percent_change_1h': -0.03781144,
#      'percent_change_24h': 0.48910922,
#      'percent_change_7d': 11.44122203,
#      'percent_change_30d': -20.71752747,
#      'percent_change_60d': -2.37039986,
#      'percent_change_90d': -28.43769114,
#      'market_cap': 537602367.9505744,
#      'market_cap_dominance': 0.0372,
#      'fully_diluted_market_cap': 1942921562.1,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 2099,
#    'name': 'ICON',
#    'symbol': 'ICX',
#    'slug': 'icon',
#    'num_market_pairs': 81,
#    'date_added': '2017-10-27T00:00:00.000Z',
#    'tags': ['platform',
#     'enterprise-solutions',
#     'interoperability',
#     'smart-contracts',
#     'kenetic-capital-portfolio',
#     'pantera-capital-portfolio'],
#    'max_supply': None,
#    'circulating_supply': 919483096,
#    'total_supply': 926210351,
#    'platform': None,
#    'cmc_rank': 95,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:08:00.000Z',
#    'quote': {'USD': {'price': 0.567371104595253,
#      'volume_24h': 51524260.70918012,
#      'volume_change_24h': 93.0887,
#      'percent_change_1h': -4.50582345,
#      'percent_change_24h': -7.98625156,
#      'percent_change_7d': -9.39204892,
#      'percent_change_30d': -32.54110147,
#      'percent_change_60d': -32.60702866,
#      'percent_change_90d': -32.24500948,
#      'market_cap': 521688139.83418304,
#      'market_cap_dominance': 0.0361,
#      'fully_diluted_market_cap': 525504989.93,
#      'last_updated': '2022-05-09T17:08:00.000Z'}}},
#   {'id': 3822,
#    'name': 'Theta Fuel',
#    'symbol': 'TFUEL',
#    'slug': 'theta-fuel',
#    'num_market_pairs': 38,
#    'date_added': '2019-03-28T00:00:00.000Z',
#    'tags': ['media', 'content-creation', 'defi', 'payments'],
#    'max_supply': None,
#    'circulating_supply': 5301214400,
#    'total_supply': 5301214400,
#    'platform': None,
#    'cmc_rank': 96,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 0.09597375010386043,
#      'volume_24h': 38053752.19173878,
#      'volume_change_24h': -7.1606,
#      'percent_change_1h': -4.90281932,
#      'percent_change_24h': -13.73850036,
#      'percent_change_7d': -27.4436566,
#      'percent_change_30d': -45.27437969,
#      'percent_change_60d': -36.4638982,
#      'percent_change_90d': -52.85077251,
#      'market_cap': 508777426.0725864,
#      'market_cap_dominance': 0.0352,
#      'fully_diluted_market_cap': 508777426.07,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 1659,
#    'name': 'Gnosis',
#    'symbol': 'GNO',
#    'slug': 'gnosis-gno',
#    'num_market_pairs': 68,
#    'date_added': '2017-05-01T00:00:00.000Z',
#    'tags': ['services',
#     'decentralized-exchange',
#     'defi',
#     'prediction-markets',
#     'kenetic-capital-portfolio',
#     'arbitrum-ecosytem'],
#    'max_supply': 10000000,
#    'circulating_supply': 1930733,
#    'total_supply': 3000000,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x6810e776880c02933d47db1b9fc05908e5386b96'},
#    'cmc_rank': 97,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 256.50235997405485,
#      'volume_24h': 7391237.94702899,
#      'volume_change_24h': 55.3385,
#      'percent_change_1h': -2.15508152,
#      'percent_change_24h': -6.93966028,
#      'percent_change_7d': -18.54464317,
#      'percent_change_30d': -34.91494981,
#      'percent_change_60d': -13.59226774,
#      'percent_change_90d': -23.22022655,
#      'market_cap': 495237570.9797869,
#      'market_cap_dominance': 0.0342,
#      'fully_diluted_market_cap': 2565023599.74,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 5864,
#    'name': 'yearn.finance',
#    'symbol': 'YFI',
#    'slug': 'yearn-finance',
#    'num_market_pairs': 273,
#    'date_added': '2020-07-18T00:00:00.000Z',
#    'tags': ['defi',
#     'yield-farming',
#     'yield-aggregator',
#     'yearn-partnerships',
#     'three-arrows-capital-portfolio',
#     'polychain-capital-portfolio',
#     'governance',
#     'blockchain-capital-portfolio',
#     'framework-ventures-portfolio',
#     'alameda-research-portfolio',
#     'parafi-capital',
#     'fantom-ecosystem',
#     'arbitrum-ecosytem',
#     'bnb-chain'],
#    'max_supply': 36666,
#    'circulating_supply': 36637.72122588,
#    'total_supply': 36666,
#    'platform': {'id': 1027,
#     'name': 'Ethereum',
#     'symbol': 'ETH',
#     'slug': 'ethereum',
#     'token_address': '0x0bc529c00c6401aef6d220be8c6ea1667f6ad93e'},
#    'cmc_rank': 98,
#    'self_reported_circulating_supply': None,
#    'self_reported_market_cap': None,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 13280.853561493088,
#      'volume_24h': 116531276.57791136,
#      'volume_change_24h': 84.5118,
#      'percent_change_1h': -8.94031835,
#      'percent_change_24h': -15.41847292,
#      'percent_change_7d': -21.7044945,
#      'percent_change_30d': -35.05475138,
#      'percent_change_60d': -30.12461462,
#      'percent_change_90d': -46.975982,
#      'market_cap': 486580210.4277193,
#      'market_cap_dominance': 0.0336,
#      'fully_diluted_market_cap': 486955776.69,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 5647,
#    'name': 'Kadena',
#    'symbol': 'KDA',
#    'slug': 'kadena',
#    'num_market_pairs': 27,
#    'date_added': '2020-05-31T00:00:00.000Z',
#    'tags': ['mineable',
#     'pow',
#     'blake2s',
#     'platform',
#     'cosmos-ecosystem',
#     'smart-contracts',
#     'coinfund-portfolio',
#     'multicoin-capital-portfolio'],
#    'max_supply': 1000000000,
#    'circulating_supply': 171287601.11586,
#    'total_supply': 1000000000,
#    'platform': None,
#    'cmc_rank': 99,
#    'self_reported_circulating_supply': 171287601.11586,
#    'self_reported_market_cap': 482589069.6072237,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 2.8174197458740604,
#      'volume_24h': 48844646.13038345,
#      'volume_change_24h': 11.6257,
#      'percent_change_1h': -4.98996224,
#      'percent_change_24h': -10.06728094,
#      'percent_change_7d': -25.03167863,
#      'percent_change_30d': -54.43246178,
#      'percent_change_60d': -54.75076295,
#      'percent_change_90d': -65.48963799,
#      'market_cap': 482589069.6072237,
#      'market_cap_dominance': 0.0334,
#      'fully_diluted_market_cap': 2817419745.87,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}},
#   {'id': 5604,
#    'name': 'Secret',
#    'symbol': 'SCRT',
#    'slug': 'secret',
#    'num_market_pairs': 35,
#    'date_added': '2020-05-19T00:00:00.000Z',
#    'tags': ['cosmos-ecosystem', 'defi', 'privacy'],
#    'max_supply': None,
#    'circulating_supply': 163295557,
#    'total_supply': 190165060,
#    'platform': None,
#    'cmc_rank': 100,
#    'self_reported_circulating_supply': 169190131,
#    'self_reported_market_cap': 481939380.9796229,
#    'last_updated': '2022-05-09T17:07:00.000Z',
#    'quote': {'USD': {'price': 2.8485076412620245,
#      'volume_24h': 14499271.47075388,
#      'volume_change_24h': 22.5776,
#      'percent_change_1h': -2.6563229,
#      'percent_change_24h': -12.20267042,
#      'percent_change_7d': -24.87155469,
#      'percent_change_30d': -47.31269836,
#      'percent_change_60d': -35.92295294,
#      'percent_change_90d': -54.04897558,
#      'market_cap': 465148641.8986385,
#      'market_cap_dominance': 0.0322,
#      'fully_diluted_market_cap': 541686626.51,
#      'last_updated': '2022-05-09T17:07:00.000Z'}}}]}

# %%
table_csv=tableobj.get_string()
with open ('output.txt', 'w') as file:
    file.write(table_csv)
